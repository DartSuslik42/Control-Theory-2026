# %% [markdown]
# # Домашнее задание 2 — задачи 2–4

# %% [markdown]
# ## Задача 2 — симуляция связанных маятников

# %% [markdown]
# ## Задача 3 — стоимость траектории

# %% [markdown]
# ## Задача 4 — подбор Kp и Kd
