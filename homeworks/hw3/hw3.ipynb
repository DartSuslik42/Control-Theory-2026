# %% [markdown]
# # Домашнее задание 3

# %% [markdown]
# ## Cart-Pole: вывод и линеаризация динамики

# %% [markdown]
# ## Семинарский notebook

# %% [markdown]
# ## LQR для двух связанных маятников

# %% [markdown]
# ## LQR для верхнего положения и Cart-Pole
